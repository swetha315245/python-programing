# %% [markdown]
# <a href="https://colab.research.google.com/github/swetha315245/python-programing/blob/main/python_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# simple program

# %%
name = "swetha"
age = 21
study = "bcom"
print("my name is;",name)
print()
print("my age is:",age)
print("my study is:",study)
# Out:
# my name is; swetha
#
# my age is: 21
# my study is: bcom

# %%
student = "priya"
clas = 10
marks = 500
print("student name is:",student)
print("student class is:",clas)
print("student marks is:",marks)
# Out:
# student name is: priya
# student class is: 10
# student marks is: 500

# %% [markdown]
# check which data type

# %%
day = 21
month = "november"
year = 2025
print("day is:",day)
print("month is:",month)
print("year is",year)
print()
print("day is:",type(day))
print("month is:",type(month))
print("year is:",type(year))
# Out:
# day is: 21
# month is: november
# year is 2025
#
# day is: <class 'int'>
# month is: <class 'str'>
# year is: <class 'int'>
